# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter
import cv2

# %%
cal_nokia = plt.imread("nokia_calib.jpg")
white_nokia = plt.imread("nokia_white.jpg")

# %%
"NOKIA"
#at y = 1000
pixel_nokia = [2269, 2121, 1972, 1955, 1919, 1876]
wav_nokia = [667.8, 584.33, 501.57, 471.31, 447.14, 338.86]

# %%
"RasPi"
# pixel_raspi = [168,120,98]
# wav_raspi = [584.33, 471.31, 447.14]
pixel_raspi = [2060, 1758.5,1726.5,1567.5, 1358.5]
wav_raspi = [584.33, 501.57, 471.31, 447.14, 338.86]

# %%
"SAMSUNG"
#at y = 1400
pixel_sam =[1640, 2002, 2391, 2435, 2535]#, 2648]
wav_sam = [667.8, 584.33, 501.57, 471.31, 447.14]#, 338.86]

# %%
# sam_cal = plt.imread("samsung_calib_f.jpg")
# sam_inc = plt.imread("samsung_incandescent_f.jpg")
# sam_led1 = plt.imread("samsung_led1_f.jpg")
# sam_led2 = plt.imread("samsung_led2_f.jpg")

sam_cal = plt.imread("samsung_calib.jpg")
sam_inc = plt.imread("samsung_incandescent.jpg")
sam_led1 = plt.imread("samsung_led1.jpg")
sam_led2 = plt.imread("samsung_led2.jpg")

# RasPi_cal = plt.imread("Helium_rawpy.png")
# RasPi_inc = plt.imread("Incan_rawpy.png")

RasPi_cal = plt.imread("raspi_helium.jpg")
RasPi_inc = plt.imread("raspi_incan.jpg")
RasPi_led = plt.imread("raspi_led.jpg")
RasPi_inc2 = plt.imread("raspi_incan2.jpg")

RasPi_cal_gray = cv2.cvtColor(RasPi_cal, cv2.COLOR_BGR2GRAY)

led1 = np.loadtxt("Romina phone light.txt")
led2 = np.loadtxt("Rene phone light.txt")
inc = np.loadtxt("incandescent.txt")

# %%
# plt.figure(dpi = 150)
# plt.imshow(RasPi_cal)

# %%
line_cal = RasPi_cal_gray[1350,1700:1800]
# plt.figure(dpi=100)
# plt.plot(line_cal, 'k')

# %%
#pixel_raspi = np.where(line_cal > 50)[0]#.tolist()

# for i in range(2,len(pixel_raspi)+2): 
#     if np.abs(pixel_raspi[i-1]-pixel_raspi[i-2]) < 2:
#         pixel_raspi.remove(pixel_raspi[i])

# %%
def wav_to_pix(fit, wav_i, wav_f):
    x_i = (wav_i - fit[0])/fit[1]
    x_f = (wav_f - fit[0])/fit[1]
    return int(x_i), int(x_f)

plt.rcParams['axes.titlesize'] = 15
plt.rcParams.update({'font.size': 15})

def Spectral_Sensitivity(pixel, wav, y, yy, cal, image, savgol, source, name):
    z1 = np.polyfit(pixel, wav, 1)
    p1 = np.poly1d(z1)
    
    
    wav_i, wav_f = 350, 750
    x_i, x_f = wav_to_pix(p1, wav_i, wav_f)
    wavelength = np.linspace(wav_i, wav_f, np.abs(x_f-x_i))
    
    source = np.interp(wavelength, source[:,0], source[:,1])
    #source = source/source.max()

    plt.figure(figsize=[15,4], facecolor = 'w')
    plt.subplot(1,2,1)
    plt.title("Calibration Image")
    plt.imshow(cal)
    plt.subplot(1,2,2)
    plt.title("Calibration Curve")
    plt.plot(pixel, wav, 'ro')
    plt.plot(pixel,p1(pixel),'k--')
    plt.ylabel("Wavelength, nm")
    plt.xlabel("Horizontal Pixel Location")
    plt.annotate('y='+ str(p1), (x_i ,550))
    plt.grid()
    plt.show()
   
    
    if p1[1] < 0:
        ROI = image[y-20:y+20,x_f:x_i]
        linescan = ROI[yy,:]/255
        r,g,b = np.flip(linescan[:,0]),np.flip(linescan[:,1]),np.flip(linescan[:,2])
        #r,g,b = r/r.max(), g/g.max(), b/b.max
        
    else:
        ROI = image[y-20:y+20,x_i:x_f]
        linescan = ROI[yy,:]/255
        r,g,b = linescan[:,0],linescan[:,1],linescan[:,2]
        #r,g,b = r/r.max(), g/g.max(), b/b.max()
    
    plt.figure(figsize=[15,4], facecolor = 'w')
    plt.subplot(1,2,1)
    plt.title("Diffracted Light Source (" + str(name) + ")")
    plt.imshow(image)
    plt.subplot(1,2,2)
    plt.title("ROI")
    plt.imshow(ROI)
    plt.axhline(yy, color = "k", marker = '.', lw = 5, alpha = 0.8)
    plt.axhline(yy, color = "y", marker = '.', lw = 3, alpha = 0.9)
    plt.show()

    plt.figure(figsize=[15,6], facecolor = 'w')
    plt.subplot(1,2,1)
    plt.title("Intensity Profile")
    plt.plot(wavelength, r, 'r')
    plt.plot(wavelength, g, 'g')
    plt.plot(wavelength, b, 'b')
    plt.plot(wavelength, source, 'k--', lw = 3)
    plt.xlabel("Wavelength")
    plt.legend(["Red","Green", "Blue", "Source"])
    plt.grid()
        
    r = savgol_filter(r,savgol,2)
    g = savgol_filter(g,savgol,2)
    b = savgol_filter(b,savgol,2)
    
    plt.subplot(1,2,2)
    plt.title("Savitzky Golay Filtering (Smoothening)")
    plt.plot(wavelength, r, 'r')
    plt.plot(wavelength, g, 'g')
    plt.plot(wavelength, b, 'b')
    plt.legend(["Red","Green", "Blue"])
    plt.xlabel("Wavelength")
    plt.grid()
    plt.show()
    
    r = r/source
    g = g/source
    b = b/source
    
    plt.figure(figsize=[15,6], facecolor = 'w')
    plt.subplot(1,2,1)
    plt.title("Spectral Sensitivity")
    plt.plot(wavelength, r, 'r')
    plt.plot(wavelength, g, 'g')
    plt.plot(wavelength, b, 'b')
    plt.xlabel("Wavelength")
    plt.legend(["Red","Green", "Blue"])
    plt.grid()
    
    plt.subplot(1,2,2)
    plt.title("Spectral Sensitivity (Normalized)")
    plt.plot(wavelength, r/r.max(), 'r')
    plt.plot(wavelength, g/g.max(), 'g')
    plt.plot(wavelength, b/b.max(), 'b')
    plt.legend(["Red","Green", "Blue"])
    plt.xlabel("Wavelength")
    plt.grid()
    plt.show()

# %%
# Spectral_Sensitivity(pixel_nokia, wav_nokia, 820, 10, cal_nokia, white_nokia, savgol = 31)

# %%
Spectral_Sensitivity(pixel_raspi, wav_raspi, 1350, 20, RasPi_cal, RasPi_inc, 21, inc, "incandescent")

# %%
Spectral_Sensitivity(pixel_raspi, wav_raspi, 1410, 20, RasPi_cal, RasPi_inc2, 21, inc, "incandescent")

# %%
Spectral_Sensitivity(pixel_raspi, wav_raspi, 1280, 9, RasPi_cal, RasPi_led, 21, led1, "LED")

# %%
Spectral_Sensitivity(pixel_sam, wav_sam, 1620, 8, sam_cal, sam_inc, 41, inc, "incandescent")

# %%
# Spectral_Sensitivity(pixel_sam, wav_sam, 1620, 8, sam_cal, sam_inc, 41, inc, "incandescent")

# %%
Spectral_Sensitivity(pixel_sam, wav_sam, 1750, 25, sam_cal, sam_led1, 31, led1, "LED")

# %%
Spectral_Sensitivity(pixel_sam, wav_sam, 1250, 5, sam_cal, sam_led2, savgol = 31)

# %%
plt.figure(figsize=[10,7], facecolor = 'w')
plt.rcParams['axes.titlesize'] = 10
plt.rcParams.update({'font.size': 15})
plt.plot(pixel, wav, 'ro')
plt.plot(pixel,p1(pixel),'k--')
plt.ylabel("Wavelength, nm")
plt.xlabel("Horizontal Pixel Location")
plt.annotate('y='+ str(p1), (1900,650))
plt.grid()

# %%
led1 = np.loadtxt("Romina phone light.txt")
led1 = np.interp(wavelength, led1[:,0], led1[:,1])
plt.plot(wavelength, led1)
led2 = np.loadtxt("Rene phone light.txt")

# %%
led1 = np.interp(wavelength, led1[:,0], led1[:,1])
plt.plot(wavelength, led1)

incandescent = np.interp(wavelength, inc[:,0], inc[:,1])
plt.plot(wavelength, incandescent)

# %%
z1 = np.polyfit(pixel_sam, wav_sam, 1)
p1 = np.poly1d(z1)

wav_i, wav_f = 350, 750
x_i, x_f = wav_to_pix(p1, wav_i, wav_f)
wavelength = np.linspace(wav_i, wav_f, np.abs(x_f-x_i))

# %%
image = sam_led1
savgol = 51
y = 1675
yy = 10
if p1[1] < 0:
        ROI = image[y-50:y+50,x_f:x_i]
        linescan = ROI[yy,:]
        r,g,b = np.flip(linescan[:,0]),np.flip(linescan[:,1]),np.flip(linescan[:,2])

else:
    ROI = image[y-50:y+50,x_i:x_f]
    linescan = ROI[yy,:]
    r,g,b = linescan[:,0],linescan[:,1],linescan[:,2]
    
r,g,b = r/led1, g/led1, b/led1
r,g,b = r/r.max(), g/g.max(), b/b.max()

# %%
plt.figure(figsize=[20,7], facecolor = 'w')
plt.rcParams['axes.titlesize'] = 20
plt.rcParams.update({'font.size': 15})
plt.subplot(1,2,1)
plt.title("Intensity Profile")
plt.plot(wavelength, r, 'r')
plt.plot(wavelength, g, 'g')
plt.plot(wavelength, b, 'b')
plt.legend(["Red","Green", "Blue"])
plt.grid()
plt.subplot(1,2,2)
plt.title("Smoothened Spectral Sensitivity")
plt.plot(wavelength, savgol_filter(r,savgol,2), 'r')
plt.plot(wavelength, savgol_filter(g,savgol,2), 'g')
plt.plot(wavelength, savgol_filter(b,savgol,2), 'b')
plt.legend(["Red","Green", "Blue"])
plt.grid()
plt.show()
# Out:
# c:\users\rene\anaconda\lib\site-packages\scipy\signal\_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-68-d7fe3677f8b3> in <module>()
# ----> 1 led1 = np.interp(wavelength, led1[:,0], led1[:,1])
#
# IndexError: too many indices for array

# %%
led1
# Out:
# array([0.02 , 0.02 , 0.02 , ..., 0.018, 0.018, 0.018])

# %%
help(np.interp)
# Out:
# Help on function interp in module numpy.lib.function_base:
#
# interp(x, xp, fp, left=None, right=None, period=None)
#     One-dimensional linear interpolation.
#
#     Returns the one-dimensional piecewise linear interpolant to a function
#     with given discrete data points (`xp`, `fp`), evaluated at `x`.
#
#     Parameters
#     ----------
#     x : array_like
#         The x-coordinates at which to evaluate the interpolated values.
#
#     xp : 1-D sequence of floats
#         The x-coordinates of the data points, must be increasing if argument
#         `period` is not specified. Otherwise, `xp` is internally sorted after
#         normalizing the periodic boundaries with ``xp = xp % period``.
#
#     fp : 1-D sequence of float or complex
#         The y-coordinates of the data points, same length as `xp`.
#
#     left : optional float or complex corresponding to fp
#         Value to return for `x < xp[0]`, default is `fp[0]`.
#
#     right : optional float or complex corresponding to fp
#         Value to return for `x > xp[-1]`, default is `fp[-1]`.
#
#     period : None or float, optional
#         A period for the x-coordinates. This parameter allows the proper
#         interpolation of angular x-coordinates. Parameters `left` and `right`
#         are ignored if `period` is specified.
#
#         .. versionadded:: 1.10.0
#
#     Returns
#     -------
#     y : float or complex (corresponding to fp) or ndarray
#         The interpolated values, same shape as `x`.
#
#     Raises
#     ------
#     ValueError
#         If `xp` and `fp` have different length
#         If `xp` or `fp` are not 1-D sequences
#         If `period == 0`
#
#     Notes
#     -----
#     Does not check that the x-coordinate sequence `xp` is increasing.
#     If `xp` is not increasing, the results are nonsense.
#     A simple check for increasing is::
#
#         np.all(np.diff(xp) > 0)
#
#     Examples
#     --------
#     >>> xp = [1, 2, 3]
#     >>> fp = [3, 2, 0]
#     >>> np.interp(2.5, xp, fp)
#     1.0
#     >>> np.interp([0, 1, 1.5, 2.72, 3.14], xp, fp)
#     array([ 3. ,  3. ,  2.5 ,  0.56,  0. ])
#     >>> UNDEF = -99.0
#     >>> np.interp(3.14, xp, fp, right=UNDEF)
#     -99.0
#
#     Plot an interpolant to the sine function:
#
#     >>> x = np.linspace(0, 2*np.pi, 10)
#     >>> y = np.sin(x)
#     >>> xvals = np.linspace(0, 2*np.pi, 50)
#     >>> yinterp = np.interp(xvals, x, y)
#     >>> import matplotlib.pyplot as plt
#     >>> plt.plot(x, y, 'o')
#     [<matplotlib.lines.Line2D object at 0x...>]
#     >>> plt.plot(xvals, yinterp, '-x')
#     [<matplotlib.lines.Line2D object at 0x...>]
#     >>> plt.show()
#
#     Interpolation with periodic x-coordinates:
#
#     >>> x = [-180, -170, -185, 185, -10, -5, 0, 365]
#     >>> xp = [190, -190, 350, -350]
#     >>> fp = [5, 10, 3, 4]
#     >>> np.interp(x, xp, fp, period=360)
#     array([7.5, 5., 8.75, 6.25, 3., 3.25, 3.5, 3.75])
#
#     Complex interpolation:
#
#     >>> x = [1.5, 4.0]
#     >>> xp = [2,3,5]
#     >>> fp = [1.0j, 0, 2+3j]
#     >>> np.interp(x, xp, fp)
#     array([ 0.+1.j ,  1.+1.5j])

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
from mpl_toolkits.mplot3d import Axes3D
import scipy.ndimage as ndimage


plt.figure(dpi = 100)
plt.rcParams.update({'font.size': 10})
flat = cv2.imread("flat.png")
flat = (flat-flat.min())/(flat.max()-flat.min())


plt.imshow(flat, cmap = 'gray')
plt.colorbar()
plt.clim(0,255)

# %%
plt.plot(flat.diagonal().T)
# Out:
# [<matplotlib.lines.Line2D at 0x167a9b0b5c0>,
#  <matplotlib.lines.Line2D at 0x167a9b0b438>,
#  <matplotlib.lines.Line2D at 0x167a9b0bb70>]

# %%
plt.figure(dpi = 100, facecolor = 'w')
plt.rcParams.update({'font.size': 10})
flat = cv2.imread("flat.png")

yyy = 400
plt.plot(flat[:,:,0].diagonal(), 'r')
plt.plot(flat[:,:,1].diagonal(), 'g')
plt.plot(flat[:,:,2].diagonal(), 'b')
plt.legend
plt.ylim(100,180)
plt.grid()
plt.title("Diagonal Transects of the Flat-Field Image")
plt.xlabel("Pixel")
#plt.colorbar()
#plt.clim(0,255)
# Out:
# Text(0.5, 0, 'Pixel')

# %%
x = flat.shape[1]
y = flat.shape[0]

# %%
X,Y = np.meshgrid(range(x),range(y))
Z = flat

# %%
fig = plt.figure(figsize = [10,6], dpi = 150, facecolor = 'w')
#plt.rcParams['axes.titlesize'] = 10
plt.rcParams.update({'font.size': 10})
ax = fig.add_subplot(111, projection='3d')
p = ax.plot_surface(X, Y, Z, rstride=10, cstride=10, cmap = 'viridis')
# p = ax.contour3D(X, Y, Z, cmap = 'inferno')
ax.elev= 120
ax.xaxis.set_ticks(np.arange(0,x+1,x/2))
ax.yaxis.set_ticks(np.arange(0,y+1,y/2))
ax.zaxis.set_ticks(np.arange(0, 256, 255/5))
ax.view_init(azim=70)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('gray level')
fig.colorbar(p)

plt.show()

# %%
dark = cv2.imread("dark.jpg")
dark = cv2.cvtColor(dark, cv2.COLOR_BGR2GRAY)

fig = plt.figure(figsize = [10,3], dpi = 100, facecolor = 'w')
plt.rcParams.update({'font.size' : 15})
plt.rcParams['axes.titlesize'] = 15
hist, bins = np.histogram(dark.ravel(), bins = 200, range = [0,10], normed = "True")
plt.bar(bins[:-1], hist/sum(hist), width=0.1, color='b')
# Out:
# C:\Users\renep\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.
#   import sys
# <BarContainer object of 200 artists>
